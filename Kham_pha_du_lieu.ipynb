# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/jobs.csv")

# %%
df.shape
# Out:
# (85470, 11)

# %%
df.info
# Out:
# <bound method DataFrame.info of                        job_title              job_type  \
# 0        trưởng phòng kinh doanh  nhân viên chính thức
# 1      nhân viên qc ngành cơ khí  nhân viên chính thức
# 2          trưởng phòng đấu thầu  nhân viên chính thức
# 3          home textile designer  nhân viên chính thức
# 4           nhân viên kinh doanh  nhân viên chính thức
# ...                          ...                   ...
# 85465         bảo trì trang trại  nhân viên chính thức
# 85466       nhân viên kinh doanh  nhân viên chính thức
# 85467               bim modeller  nhân viên chính thức
# 85468         nhân viên gia công  nhân viên chính thức
# 85469           business analyst  nhân viên chính thức
#
#                position_level         city     experience  \
# 0      trưởng nhóm , giám sát  hồ chí minh  lên đến 1 năm
# 1                   nhân viên  hồ chí minh     trên 1 năm
# 2      trưởng nhóm , giám sát  hồ chí minh      5 - 7 năm
# ...

# %%
df.head()
# Out:
#                    job_title              job_type          position_level  \
# 0    trưởng phòng kinh doanh  nhân viên chính thức  trưởng nhóm , giám sát
# 1  nhân viên qc ngành cơ khí  nhân viên chính thức               nhân viên
# 2      trưởng phòng đấu thầu  nhân viên chính thức  trưởng nhóm , giám sát
# 3      home textile designer  nhân viên chính thức               nhân viên
# 4       nhân viên kinh doanh  nhân viên chính thức               nhân viên
#
#           city     experience  \
# 0  hồ chí minh  lên đến 1 năm
# 1  hồ chí minh     trên 1 năm
# 2  hồ chí minh      5 - 7 năm
# 3     hưng yên     5 - 15 năm
# 4  hồ chí minh     trên 1 năm
#
#                                               skills  \
# 0                                                NaN
# 1  production planning staff, chuyên viên iso, th...
# 2  trưởng phòng xây dựng, trưởng phòng đấu thầu, ...
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# job_title             7
# job_type              0
# position_level        0
# city                 32
# experience            0
# skills            11294
# job_fields         7625
# salary                0
# salary_min            0
# salary_max            0
# unit                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(40531)

# %% [markdown]
# Dataset gồm 85.470 tin tuyển dụng.
#
# Có 11 thuộc tính.
#
# Các cột skills và job_fields có nhiều giá trị thiếu.
#
# Cần tiến hành làm sạch dữ liệu.
